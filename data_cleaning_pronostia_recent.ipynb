# %%
from __future__ import print_function
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
import warnings
import tensorflow as tf
import seaborn as sns
import sklearn
import random
import math
import time
import os
import pywt  # Bibliothèque pour les ondelettes

from scipy.stats import kurtosis, skew
from numpy.fft import fft


from lime.lime_tabular import RecurrentTabularExplainer
from tqdm import tqdm
from sklearn.metrics import mean_squared_error, r2_score 
from sklearn.model_selection import GroupKFold
from sklearn import preprocessing
from keras import backend as K
from sklearn.preprocessing import MinMaxScaler , StandardScaler
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, Activation, GRU
from scipy import optimize
from tensorflow.keras import optimizers


from sp_modif.model_function import *
from sp_modif.methods import *
from sp_modif.data_prep import *
from sp_modif.evaluator import *
from sp_modif.SHAP import *
from sp_modif.L2X import *
from methods import *

# %matplotlib inline
warnings.filterwarnings('ignore')

SEED = 0
def set_seed(seed=SEED):
    os.environ['PYTHONHASHSEED'] = str(SEED)
    random.seed(SEED)
    np.random.seed(SEED)
    tf.random.set_seed(SEED)

# Appeler la fonction pour fixer le seed
set_seed(SEED)

# %%
def extract_temporal_features(signal):
    """Extrait les caractéristiques temporelles d'un signal."""
    rms = np.sqrt(np.mean(signal**2))
    mean_abs = np.mean(np.abs(signal))
    max_abs = np.max(np.abs(signal))
    energy = np.sum(signal**2)
    
    features = {
        'mean': signal.mean(),
        'std': signal.std(),
        'peak_to_peak': signal.max() - signal.min(),
        'rms': rms,
        'mean_abs': mean_abs,
        'max_abs': max_abs,
        'skewness': skew(signal),
        'kurtosis': kurtosis(signal),
        'form_factor': rms / mean_abs if mean_abs != 0 else 0,
        'crest_factor': signal.max() / rms if rms != 0 else 0,
        'impulse_factor': signal.max() / mean_abs if mean_abs != 0 else 0,
        'margin_factor': signal.max() / (np.mean(np.sqrt(np.abs(signal))) ** 2) if np.mean(np.sqrt(np.abs(signal))) != 0 else 0,
        'energy': energy
    }
    
    # Moments centrés (ordre 5 à 11)
    for order in range(5, 12):
        features[f'moment_{order}'] = np.mean((signal - signal.mean())**order)
    
    return features

def extract_frequency_features(signal, sampling_rate=25600):
    """Extrait les caractéristiques fréquentielles d'un signal donné."""
    signal = np.asarray(signal)
    if signal.size == 0:
        raise ValueError("Signal vide : impossible de calculer des caractéristiques fréquentielles.")

    # FFT
    N = len(signal)
    freqs = fft(signal)
    freqs = np.abs(freqs[:N // 2])  # Composantes positives
    freq_bins = np.fft.fftfreq(N, d=1/sampling_rate)[:N // 2]

    # Normalisation pour l'entropie spectrale
    power_spectrum = freqs**2
    power_spectrum /= np.sum(power_spectrum)

    # Calcul des caractéristiques
    max_amplitude = np.max(freqs)
    mean_freq = np.mean(freqs)
    rms_freq = np.sqrt(np.mean(freqs**2))
    variance_freq = np.var(freqs)
    std_freq = np.std(freqs)
    kurtosis_freq = kurtosis(freqs)
    skewness_freq = skew(freqs)
    peak_freq = freq_bins[np.argmax(freqs)]
    form_factor_freq = rms_freq / mean_freq if mean_freq != 0 else 0
    crest_factor_freq = max_amplitude / rms_freq if rms_freq != 0 else 0
    spectral_entropy = -np.sum(power_spectrum * np.log2(power_spectrum + 1e-10))
    
    # Division en bandes de fréquence
    num_bands = 25
    band_width = (sampling_rate / 2) / num_bands
    energy_bands = {}
    for band in range(num_bands):
        low = band * band_width
        high = (band + 1) * band_width
        energy_bands[f'energy_band_{band}'] = np.sum(power_spectrum[(freq_bins >= low) & (freq_bins < high)])
    
    features = {
        'max_amplitude': max_amplitude,
        'mean_freq': mean_freq,
        'rms_freq': rms_freq,
        'variance_freq': variance_freq,
        'std_freq': std_freq,
        'kurtosis_freq': kurtosis_freq,
        'skewness_freq': skewness_freq,
        'peak_freq': peak_freq,
        'form_factor_freq': form_factor_freq,
        'crest_factor_freq': crest_factor_freq,
        'spectral_entropy': spectral_entropy
    }
    features.update(energy_bands)
    return features

def extract_derivative_features(signal):
    """Extrait les caractéristiques temporelles de la dérivée du signal."""
    derivative = np.diff(signal, prepend=signal[0])
    return extract_temporal_features(derivative)

def extract_integral_features(signal):
    """Extrait les caractéristiques temporelles de l'intégrale du signal."""
    integral = np.cumsum(signal)
    return extract_temporal_features(integral)

def extract_imf_features(signal, num_imfs=5):
    """Extrait les caractéristiques des IMFs à partir d'une décomposition en ondelettes."""
    coeffs = pywt.wavedec(signal, wavelet='db4', level=num_imfs)
    features = {}
    for i, coeff in enumerate(coeffs[:num_imfs]):
        features[f'imf_rms_{i}'] = np.sqrt(np.mean(coeff**2))
        features[f'imf_energy_{i}'] = np.sum(coeff**2)
        features[f'imf_entropy_{i}'] = -np.sum((coeff**2 / np.sum(coeff**2)) * np.log2(coeff**2 / np.sum(coeff**2) + 1e-10))
    return features

def extract_features(signal, sampling_rate=25600):
    """Extrait toutes les caractéristiques temporelles, fréquentielles, dérivées et intégrées."""
    temporal_features = extract_temporal_features(signal)
    frequency_features = extract_frequency_features(signal, sampling_rate)
    derivative_features = extract_derivative_features(signal)
    integral_features = extract_integral_features(signal)
    imf_features = extract_imf_features(signal)

    # Fusionner toutes les caractéristiques dans un seul dictionnaire
    all_features = {
        **temporal_features,
        **frequency_features,
        **{f'derivative_{k}': v for k, v in derivative_features.items()},
        **{f'integral_{k}': v for k, v in integral_features.items()},
        **imf_features
    }
    return all_features

# %%
def calculate_rul(data, time_col='time_seconds', bearing_col='bearing_id'):
    """
    Calcule le Remaining Useful Life (RUL) et le RUL normalisé pour chaque échantillon.

    :param data: DataFrame contenant les données avec les colonnes `time_col` et `bearing_col`
    :param time_col: Nom de la colonne contenant les temps (par défaut `time_seconds`)
    :param bearing_col: Nom de la colonne contenant les IDs des roulements (par défaut `bearing_id`)
    :return: DataFrame avec deux colonnes supplémentaires `RUL` et `RUL_norm`
    """
    # Étape 1 : Trouver le temps total (fin de vie) pour chaque roulement
    total_time = data.groupby(bearing_col)[time_col].max()

    # Étape 2 : Calculer le RUL pour chaque échantillon
    data['RUL'] = data.apply(lambda row: total_time[row[bearing_col]] - row[time_col], axis=1)

    # Étape 3 : Normaliser le RUL
    max_rul = data['RUL'].max()  # Valeur maximale de RUL
    data['RUL_norm'] = data['RUL'] / max_rul if max_rul > 0 else data['RUL']

    return data

# %%
# Chargement des données
DEFAULT_SAMPLING_RATE = 100  # Fréquence d'échantillonnage en Hz

def load_vibration_data(data_folder, idx=None):
    """Charge les fichiers de vibration et calcule le temps en secondes pour chaque échantillon."""
    vibration_files = [f for f in os.listdir(data_folder) if f.startswith('acc_') and f.endswith('.csv')]
    if not vibration_files:
        print("No vibration files found in the specified folder.")
        return pd.DataFrame()  # Retourne un DataFrame vide si aucun fichier n'est trouvé
    
    vibration_data = []

    for file in vibration_files:
        file_path = os.path.join(data_folder, file)
        df = pd.read_csv(file_path, names=['Hour', 'Minute', 'Second', 'Microsecond', 'Horizontal_Accel', 'Vertical_Accel'])
        
        # Extraction de l'identifiant du roulement
        bearing_id = file.split('_')[1].split('.')[0]
        df['bearing_id'] = idx + bearing_id
        
        # Calcul du temps en secondes pour chaque échantillon
        df['time_seconds'] = df['Hour'] * 3600 + df['Minute'] * 60 + df['Second'] + df['Microsecond'] * 1e-6
        vibration_data.append(df)

    # Concaténation de toutes les données de vibration en un DataFrame unique
    result = pd.concat(vibration_data, ignore_index=True)
    print(f"Loaded data shape: {result.shape}")
    print(result.head())
    return result

# Calcul du temps total et du RUL normalisé
def calculate_total_time(vibration_data):
    """Calcule le temps total de l'expérience pour chaque roulement."""
    return vibration_data.groupby('bearing_id')['time_seconds'].max()

def calculate_normalized_rul(vibration_data, total_time):
    """Calcule le RUL normalisé pour chaque échantillon."""
    vibration_data['RUL_norm'] = vibration_data.apply(
        lambda row: 1 - (total_time[row['bearing_id']] - row['time_seconds']) / total_time[row['bearing_id']],
        axis=1
    )
    return vibration_data

# Division en fenêtres
def split_into_windows(data, window_size, sampling_rate=DEFAULT_SAMPLING_RATE):
    """Divise les données en fenêtres de taille définie."""
    samples_per_window = int(window_size * sampling_rate)
    num_windows = len(data) // samples_per_window
    print(f"Data size: {len(data)}, Samples per window: {samples_per_window}, Number of windows: {num_windows}")
    if num_windows == 0:
        print("Warning: Not enough data to form a window.")
    windows = [data[i * samples_per_window:(i + 1) * samples_per_window] for i in range(num_windows)]
    return windows

# Pipeline principal
def main_pipeline(data_folder, idx, window_size=10, sampling_rate=DEFAULT_SAMPLING_RATE):
    """Pipeline complet pour traiter les données."""
    # Charger les données
    vibration_data = load_vibration_data(data_folder, idx)
    if vibration_data.empty:
        print("No data loaded. Check your data folder.")
        return pd.DataFrame()
    
    # Calculer le temps total et le RUL normalisé
    # total_time = calculate_total_time(vibration_data)
    vibration_data = calculate_rul(vibration_data)
    print(f"Data after RUL calculation: {vibration_data.shape}")
    
    # Extraire les caractéristiques
    features_df = extract_features_per_window(vibration_data, window_size, sampling_rate)
    print(f"Extracted features shape: {features_df.shape}")
    
    return features_df

def plot_signal_pronostia(df, signal_name, unit=None):
    #     train = df
    plt.figure(figsize=(13,5))
    if unit:
        plt.plot('RUL_norm', signal_name,
                data=df[df['Unit']==unit])
    else:
        for i in df['Unit'].unique():
            # if (i % 10 == 0):  # only ploting every 10th unit_nr
            plt.plot('RUL_norm', signal_name, data=df[df['Unit']==i])
            
    plt.xlim(2560, 0)  # reverse the x-axis so RUL counts down to zero
    plt.xticks(np.arange(0, 2560, 250))
    plt.ylabel(signal_name)
    plt.xlabel('Remaining Use fulLife')
    #plt.savefig(signal_name+'.jpeg')
    plt.show()
def extract_time_frequency_features(signal, wavelet='db4', level=3):
    """Extrait les caractéristiques temps-fréquence à partir d'une décomposition en ondelettes."""
    coeffs = pywt.wavedec(signal, wavelet, level=level)
    features = {}
    for i, coeff in enumerate(coeffs):
        features[f'wavelet_energy_level_{i}'] = np.sum(coeff**2)
    return features

def extract_features_per_window(data, window_size, sampling_rate=DEFAULT_SAMPLING_RATE):
    """Extrait les caractéristiques de chaque fenêtre de données."""
    features_list = []

    for bearing_id, group in data.groupby('bearing_id'):
        print(f"Processing bearing: {bearing_id}, Data size: {len(group)}")
        horizontal_signal = group['Horizontal_Accel'].values
        vertical_signal = group['Vertical_Accel'].values
        
        horizontal_windows = split_into_windows(horizontal_signal, window_size, sampling_rate)
        vertical_windows = split_into_windows(vertical_signal, window_size, sampling_rate)
        
        # total_duration = group['time_seconds'].max()
        
        for i, (h_window, v_window) in enumerate(zip(horizontal_windows, vertical_windows)):
            # Extraction des caractéristiques temporelles, fréquentielles et temps-fréquence
            temporal_features_h = extract_temporal_features(h_window)
            # temporal_features_v = extract_temporal_features(v_window)
            # frequency_features_h = extract_frequency_features(h_window, sampling_rate)
            # frequency_features_v = extract_frequency_features(v_window, sampling_rate)
            # time_frequency_features_h = extract_imf_features(h_window)  # IMFs pour horizontal
            # time_frequency_features_v = extract_imf_features(v_window)  # IMFs pour vertical
            
            # # Extraction des caractéristiques pour la dérivée et l'intégrale
            # derivative_features_h = extract_derivative_features(h_window)
            # derivative_features_v = extract_derivative_features(v_window)
            # integral_features_h = extract_integral_features(h_window)
            # integral_features_v = extract_integral_features(v_window)
            
            # Fusionner toutes les caractéristiques
            features = {f"{k}_h": v for k, v in temporal_features_h.items()}
            # features.update({f"{k}_v": v for k, v in temporal_features_v.items()})
            # features.update({f"{k}_freq_h": v for k, v in frequency_features_h.items()})
            # features.update({f"{k}_freq_v": v for k, v in frequency_features_v.items()})
            # features.update({f"{k}_tf_h": v for k, v in time_frequency_features_h.items()})
            # features.update({f"{k}_tf_v": v for k, v in time_frequency_features_v.items()})
            # features.update({f"derivative_{k}_h": v for k, v in derivative_features_h.items()})
            # features.update({f"derivative_{k}_v": v for k, v in derivative_features_v.items()})
            # features.update({f"integral_{k}_h": v for k, v in integral_features_h.items()})
            # features.update({f"integral_{k}_v": v for k, v in integral_features_v.items()})
            
            # # Calculer le RUL normalisé pour cette fenêtre
            # start_time_window = i * window_size  # Temps de début de la fenêtre en secondes
            # RUL = max(0, total_duration - start_time_window)  # RUL décroît avec le temps
            # RUL_norm = RUL / total_duration if total_duration > 0 else 0  # RUL normalisé
            # Ajouter le RUL normalisé depuis les données
            index = int(i * window_size*100) # Assurez-vous que l'index est entier
            if index < len(group):
                features['RUL'] = np.mean(group.iloc[index:index+10]['RUL'])
            
            # Ajouter des informations contextuelles
            features['bearing_id'] = bearing_id
            features['window_index'] = i
            # features['RUL_norm'] = RUL_norm  # Ajout de RUL normalisé
            
            # Ajouter les caractéristiques extraites à la liste
            features_list.append(features)

    return pd.DataFrame(features_list)

# %%
vibration_data_with_rul = load_vibration_data(data_folder, idx=idx)
# Out:
# Loaded data shape: (7175680, 8)
#    Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 0     9      39      39      65664.0             0.552          -0.146
# 1     9      39      39      65703.0             0.501          -0.480
# 2     9      39      39      65742.0             0.138           0.435
# 3     9      39      39      65781.0            -0.423           0.240
# 4     9      39      39      65820.0            -0.802           0.020
#
#   bearing_id  time_seconds
# 0   1_100001  34779.065664
# 1   1_100001  34779.065703
# 2   1_100001  34779.065742
# 3   1_100001  34779.065781
# 4   1_100001  34779.065820

# %%
vibration_data_with_rul[vibration_data_with_rul.bearing_id=='1_100003']
# Out:
#       Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 5120     9      39      59      65664.0             0.207          -0.686
# 5121     9      39      59      65703.0            -0.099           0.147
# 5122     9      39      59      65742.0            -0.151          -0.195
# 5123     9      39      59      65781.0            -0.358          -0.584
# 5124     9      39      59      65820.0            -0.424          -0.019
# ...    ...     ...     ...          ...               ...             ...
# 7675     9      39      59     165470.0            -0.300           0.050
# 7676     9      39      59     165510.0            -0.538           0.295
# 7677     9      39      59     165550.0            -0.544           0.489
# 7678     9      39      59     165580.0            -0.178          -0.341
# 7679     9      39      59     165620.0             0.854          -0.102
#
#      bearing_id  time_seconds
# 5120   1_100003  34799.065664
# 5121   1_100003  34799.065703
# 5122   1_100003  34799.065742
# 5123   1_100003  34799.065781
# 5124   1_100003  34799.065820
# ...         ...           ...
# 7675   1_100003  34799.165470
# 7676   1_100003  34799.165510
# 7677   1_100003  34799.165550
# 7678   1_100003  34799.165580
# 7679   1_100003  34799.165620
#
# [2560 rows x 8 columns]

# %%
pip uninstall scipy
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\programdata\anaconda3\envs\tensorflow_env\lib\site-packages (1.15.0)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in c:\programdata\anaconda3\envs\tensorflow_env\lib\site-packages (from scipy) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
from tsfresh import extract_features
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 from tsfresh import extract_features
#
# File c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\tsfresh\__init__.py:27
#      22 from logging import NullHandler
#      24 logging.getLogger(__name__).addHandler(NullHandler())
# ---> 27 from tsfresh.convenience.relevant_extraction import (  # noqa: E402
#      28     extract_relevant_features,
#      29 )
#      30 from tsfresh.feature_extraction import extract_features  # noqa: E402
#      31 from tsfresh.feature_selection import select_features  # noqa: E402
#
# File c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\tsfresh\convenience\relevant_extraction.py:8
#       5 import pandas as pd
#       7 from tsfresh import defaults
# ----> 8 from tsfresh.feature_extraction import extract_features
#       9 from tsfresh.feature_selection import select_features
#      10 from tsfresh.utilities.dataframe_functions import (
#      11     get_ids,
#      12     impute,
#      13     restrict_input_to_index,
#      14 )
#
# File c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\tsfresh\feature_extraction\__init__.py:5
#       1 """
#       2 The :mod:`tsfresh.feature_extraction` module contains methods to extract the features from the time series
#       3 """
# ----> 5 from tsfresh.feature_extraction.extraction import extract_features
#       6 from tsfresh.feature_extraction.settings import (
#       7     ComprehensiveFCParameters,
#       8     EfficientFCParameters,
#       9     MinimalFCParameters,
#      10 )
#
# File c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\tsfresh\feature_extraction\extraction.py:15
#      12 import pandas as pd
#      14 from tsfresh import defaults
# ---> 15 from tsfresh.feature_extraction import feature_calculators
#      16 from tsfresh.feature_extraction.data import to_tsdata
#      17 from tsfresh.feature_extraction.settings import ComprehensiveFCParameters
#
# File c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\tsfresh\feature_extraction\feature_calculators.py:30
#      28 import stumpy
#      29 from numpy.linalg import LinAlgError
# ---> 30 from scipy.signal import cwt, find_peaks_cwt, ricker, welch
#      31 from scipy.stats import linregress
#      32 from statsmodels.tools.sm_exceptions import MissingDataError
#
# ImportError: cannot import name 'cwt' from 'scipy.signal' (c:\ProgramData\anaconda3\envs\tensorflow_env\lib\site-packages\scipy\signal\__init__.py)

# %%
from tqdm import tqdm
list_train_df = []
list_idx = ['1_1']
# list_idx = ['1_2']

for idx in tqdm(list_idx):
    folder = 'PRONOSTIA/Learning_set/'
    bearing = 'Bearing' + idx
    base_dir = os.path.join(folder, bearing)
    data_folder = base_dir
    vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 10)
    # print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
    list_train_df.append(vibration_data_with_rul)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# Loaded data shape: (7175680, 8)
#    Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 0     9      39      39      65664.0             0.552          -0.146
# 1     9      39      39      65703.0             0.501          -0.480
# 2     9      39      39      65742.0             0.138           0.435
# 3     9      39      39      65781.0            -0.423           0.240
# 4     9      39      39      65820.0            -0.802           0.020
#
#   bearing_id  time_seconds
# 0   1_100001  34779.065664
# 1   1_100001  34779.065703
# 2   1_100001  34779.065742
# 3   1_100001  34779.065781
# 4   1_100001  34779.065820
# Data after RUL calculation: (7175680, 10)
#   0%|          | 0/1 [01:17<?, ?it/s]
# Processing bearing: 1_100001, Data size: 2560
# Data size: 2560, Samples per window: 1000, Number of windows: 2
# Data size: 2560, Samples per window: 1000, Number of windows: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 11
#       9 base_dir = os.path.join(folder, bearing)
#      10 data_folder = base_dir
# ---> 11 vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 10)
#      12 # print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
#      13 list_train_df.append(vibration_data_with_rul)
#
# Cell In[16], line 70, in main_pipeline(data_folder, idx, window_size, sampling_rate)
#      67 print(f"Data after RUL calculation: {vibration_data.shape}")
#      69 # Extraire les caractéristiques
# ---> 70 features_df = extract_features_per_window(vibration_data, window_size, sampling_rate)
#      71 print(f"Extracted features shape: {features_df.shape}")
#      73 return features_df
#
# Cell In[16], line 143, in extract_features_per_window(data, window_size, sampling_rate)
#     141 # # Calculer le RUL normalisé pour cette fenêtre
#     142 start_time_window = i * window_size  # Temps de début de la fenêtre en secondes
# --> 143 RUL = max(0, total_duration - start_time_window)  # RUL décroît avec le temps
#     144 RUL_norm = RUL / total_duration if total_duration > 0 else 0  # RUL normalisé
#     145 # Ajouter le RUL normalisé depuis les données
#
# NameError: name 'total_duration' is not defined

# %%
# Utilisation de la fonction principale
from tqdm import tqdm
list_train_df = []
list_idx = ['1_1', '1_2', '2_1', '2_2']
# list_idx = ['1_2']

for idx in tqdm(list_idx):
    folder = 'PRONOSTIA/Learning_set/'
    bearing = 'Bearing' + idx
    base_dir = os.path.join(folder, bearing)
    data_folder = base_dir
    vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 0.1)
    # print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
    list_train_df.append(vibration_data_with_rul)
    
# idx = '1_2'
# folder = 'PRONOSTIA/Learning_set/'
# bearing = 'Bearing' + idx
# base_dir = os.path.join(folder, bearing)


# data_folder = base_dir
# vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 0.1)
# print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded data shape: (7175680, 8)
#    Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 0     9      39      39      65664.0             0.552          -0.146
# 1     9      39      39      65703.0             0.501          -0.480
# 2     9      39      39      65742.0             0.138           0.435
# 3     9      39      39      65781.0            -0.423           0.240
# 4     9      39      39      65820.0            -0.802           0.020
#
#   bearing_id  time_seconds
# 0   1_100001  34779.065664
# 1   1_100001  34779.065703
# 2   1_100001  34779.065742
# 3   1_100001  34779.065781
# 4   1_100001  34779.065820
# Data after RUL calculation: (7175680, 10)
# Processing bearing: 1_100001, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100002, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100003, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100004, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100005, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100006, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100007, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100008, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100009, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100010, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100011, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100012, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100013, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100014, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100015, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100016, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100017, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100018, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100019, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100020, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100021, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100022, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100023, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100024, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100025, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100026, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100027, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100028, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100029, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100030, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100031, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100032, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100033, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100034, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100035, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100036, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100037, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100038, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100039, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100040, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100041, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100042, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100043, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100044, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100045, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100046, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100047, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100048, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100049, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100050, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100051, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100052, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100053, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100054, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100055, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100056, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100057, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100058, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100059, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100060, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100061, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100062, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100063, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100064, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100065, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100066, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100067, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100068, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100069, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100070, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100071, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100072, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100073, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100074, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100075, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100076, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100077, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100078, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100079, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100080, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100081, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100082, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100083, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100084, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100085, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100086, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100087, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100088, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100089, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100090, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100091, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100092, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100093, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100094, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100095, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100096, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100097, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100098, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100099, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100100, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100101, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100102, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100103, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100104, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100105, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100106, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100107, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100108, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100109, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100110, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100111, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100112, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100113, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100114, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100115, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100116, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100117, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100118, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100119, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100120, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100121, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100122, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100123, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100124, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100125, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100126, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100127, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100128, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100129, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100130, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100131, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100132, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100133, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100134, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100135, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100136, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100137, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100138, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100139, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100140, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100141, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100142, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100143, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100144, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100145, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100146, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100147, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100148, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100149, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100150, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100151, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100152, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100153, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100154, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100155, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100156, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100157, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100158, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100159, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100160, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100161, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100162, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100163, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100164, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100165, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100166, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100167, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100168, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100169, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100170, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100171, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100172, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100173, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100174, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100175, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100176, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100177, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100178, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100179, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100180, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100181, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100182, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100183, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100184, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100185, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100186, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100187, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100188, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100189, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100190, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100191, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100192, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100193, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100194, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100195, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100196, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100197, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100198, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100199, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100200, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100201, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100202, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100203, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100204, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100205, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100206, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100207, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100208, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100209, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100210, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100211, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100212, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100213, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100214, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100215, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100216, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100217, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100218, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100219, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100220, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100221, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100222, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100223, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100224, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100225, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100226, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100227, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100228, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100229, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100230, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100231, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100232, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100233, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100234, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100235, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100236, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100237, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100238, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100239, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100240, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100241, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100242, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100243, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100244, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100245, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100246, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100247, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100248, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100249, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100250, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100251, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100252, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100253, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100254, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100255, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100256, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100257, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100258, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100259, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100260, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100261, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100262, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100263, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100264, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100265, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100266, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100267, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100268, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100269, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100270, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100271, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_100272, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# ...
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200707, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200708, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200709, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200710, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200711, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200712, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200713, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200714, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200715, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200716, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200717, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200718, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200719, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200720, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200721, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200722, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200723, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200724, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200725, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200726, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200727, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200728, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200729, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200730, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200731, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200732, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200733, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200734, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200735, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200736, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200737, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200738, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200739, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200740, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200741, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200742, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200743, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200744, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200745, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200746, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200747, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200748, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200749, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200750, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200751, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200752, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200753, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200754, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200755, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200756, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200757, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200758, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200759, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200760, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200761, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200762, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200763, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200764, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200765, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200766, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200767, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200768, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200769, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200770, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200771, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200772, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200773, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200774, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200775, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200776, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200777, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200778, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200779, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200780, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200781, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200782, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200783, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200784, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200785, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200786, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200787, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200788, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200789, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200790, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200791, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200792, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200793, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200794, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200795, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200796, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_200797, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# 100%|██████████| 4/4 [20:37<00:00, 309.29s/it]
# Extracted features shape: (204032, 23)

# %%
# print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
import pickle
nom_fichier = "df_training_rul.pkl"

# Sauvegarde de la liste dans un fichier avec pickle
with open(nom_fichier, "wb") as fichier:
    pickle.dump(list_train_df, fichier)

print(f"Liste sauvegardée dans le fichier '{nom_fichier}'.")
# Out:
# Liste sauvegardée dans le fichier 'df_training_rul.pkl'.

# %%
# Utilisation de la fonction principale
from tqdm import tqdm
list_validation_df = []
list_idx = ['1_3', '1_4', '2_3', '2_4']
for idx in tqdm(list_idx):
    folder = 'PRONOSTIA/Test_set/'
    bearing = 'Bearing' + idx
    base_dir = os.path.join(folder, bearing)
    data_folder = base_dir
    vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 0.1)
    # print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
    list_validation_df.append(vibration_data_with_rul)
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Loaded data shape: (4613120, 8)
#    Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 0     8      33       1     378160.0             0.092           0.044
# 1     8      33       1     378200.0            -0.025           0.432
# 2     8      33       1     378240.0            -0.104           0.008
# 3     8      33       1     378280.0             0.056          -0.264
# 4     8      33       1     378320.0             0.074          -0.195
#
#   bearing_id  time_seconds
# 0   1_300001   30781.37816
# 1   1_300001   30781.37820
# 2   1_300001   30781.37824
# 3   1_300001   30781.37828
# 4   1_300001   30781.37832
# Data after RUL calculation: (4613120, 10)
# Processing bearing: 1_300001, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300002, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300003, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300004, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300005, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300006, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300007, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300008, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300009, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300010, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300011, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300012, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300013, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300014, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300015, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300016, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300017, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300018, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300019, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300020, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300021, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300022, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300023, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300024, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300025, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300026, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300027, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300028, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300029, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300030, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300031, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300032, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300033, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300034, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300035, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300036, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300037, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300038, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300039, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300040, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300041, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300042, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300043, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300044, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300045, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300046, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300047, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300048, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300049, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300050, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300051, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300052, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300053, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300054, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300055, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300056, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300057, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300058, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300059, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300060, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300061, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300062, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300063, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300064, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300065, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300066, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300067, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300068, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300069, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300070, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300071, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300072, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300073, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300074, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300075, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300076, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300077, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300078, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300079, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300080, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300081, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300082, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300083, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300084, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300085, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300086, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300087, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300088, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300089, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300090, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300091, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300092, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300093, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300094, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300095, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300096, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300097, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300098, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300099, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300100, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300101, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300102, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300103, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300104, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300105, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300106, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300107, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300108, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300109, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300110, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300111, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300112, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300113, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300114, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300115, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300116, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300117, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300118, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300119, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300120, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300121, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300122, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300123, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300124, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300125, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300126, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300127, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300128, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300129, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300130, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300131, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300132, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300133, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300134, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300135, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300136, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300137, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300138, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300139, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300140, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300141, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300142, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300143, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300144, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300145, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300146, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300147, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300148, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300149, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300150, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300151, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300152, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300153, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300154, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300155, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300156, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300157, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300158, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300159, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300160, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300161, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300162, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300163, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300164, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300165, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300166, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300167, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300168, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300169, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300170, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300171, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300172, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300173, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300174, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300175, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300176, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300177, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300178, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300179, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300180, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300181, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300182, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300183, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300184, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300185, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300186, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300187, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300188, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300189, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300190, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300191, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300192, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300193, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300194, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300195, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300196, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300197, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300198, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300199, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300200, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300201, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300202, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300203, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300204, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300205, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300206, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300207, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300208, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300209, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300210, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300211, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300212, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300213, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300214, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300215, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300216, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300217, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300218, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300219, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300220, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300221, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300222, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300223, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300224, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300225, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300226, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300227, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300228, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300229, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300230, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300231, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300232, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300233, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300234, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300235, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300236, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300237, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300238, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300239, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300240, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300241, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300242, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300243, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300244, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300245, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300246, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300247, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300248, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300249, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300250, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300251, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300252, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300253, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300254, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300255, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300256, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300257, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300258, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300259, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300260, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300261, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300262, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300263, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300264, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300265, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300266, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300267, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300268, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300269, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300270, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300271, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_300272, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# ...
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400522, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400523, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400524, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400525, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400526, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400527, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400528, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400529, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400530, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400531, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400532, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400533, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400534, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400535, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400536, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400537, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400538, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400539, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400540, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400541, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400542, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400543, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400544, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400545, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400546, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400547, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400548, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400549, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400550, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400551, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400552, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400553, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400554, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400555, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400556, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400557, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400558, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400559, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400560, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400561, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400562, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400563, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400564, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400565, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400566, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400567, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400568, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400569, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400570, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400571, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400572, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400573, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400574, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400575, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400576, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400577, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400578, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400579, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400580, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400581, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400582, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400583, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400584, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400585, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400586, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400587, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400588, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400589, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400590, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400591, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400592, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400593, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400594, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400595, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400596, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400597, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400598, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400599, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400600, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400601, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400602, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400603, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400604, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400605, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400606, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400607, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400608, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400609, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400610, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400611, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_400612, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# 100%|██████████| 4/4 [17:50<00:00, 267.62s/it]
# Extracted features shape: (156672, 23)

# %%
# print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
import pickle
nom_fichier = "df_validation_rul.pkl"

# Sauvegarde de la liste dans un fichier avec pickle
with open(nom_fichier, "wb") as fichier:
    pickle.dump(list_validation_df, fichier)

print(f"Liste sauvegardée dans le fichier '{nom_fichier}'.")
# Out:
# Liste sauvegardée dans le fichier 'df_validation_rul.pkl'.

# %%
# Utilisation de la fonction principale
from tqdm import tqdm
list_test_df = []
list_idx = ['1_5', '1_6', '1_7', '2_5', '2_6', '2_7']
for idx in tqdm(list_idx):
    folder = 'PRONOSTIA/Test_set/'
    bearing = 'Bearing' + idx
    base_dir = os.path.join(folder, bearing)
    data_folder = base_dir
    vibration_data_with_rul = main_pipeline(data_folder, idx=idx,window_size= 0.1)
    # print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
    list_test_df.append(vibration_data_with_rul)
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]
# Loaded data shape: (5893120, 8)
#    Hour  Minute  Second  Microsecond  Horizontal_Accel  Vertical_Accel  \
# 0     9      20      24     212540.0             0.211           0.281
# 1     9      20      24     212580.0             0.268          -0.206
# 2     9      20      24     212620.0             0.306          -0.444
# 3     9      20      24     212660.0             0.226           0.111
# 4     9      20      24     212700.0            -0.025           0.077
#
#   bearing_id  time_seconds
# 0   1_500001   33624.21254
# 1   1_500001   33624.21258
# 2   1_500001   33624.21262
# 3   1_500001   33624.21266
# 4   1_500001   33624.21270
# Data after RUL calculation: (5893120, 10)
# Processing bearing: 1_500001, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500002, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500003, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500004, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500005, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500006, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500007, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500008, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500009, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500010, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500011, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500012, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500013, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500014, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500015, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500016, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500017, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500018, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500019, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500020, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500021, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500022, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500023, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500024, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500025, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500026, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500027, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500028, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500029, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500030, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500031, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500032, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500033, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500034, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500035, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500036, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500037, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500038, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500039, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500040, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500041, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500042, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500043, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500044, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500045, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500046, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500047, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500048, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500049, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500050, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500051, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500052, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500053, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500054, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500055, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500056, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500057, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500058, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500059, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500060, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500061, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500062, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500063, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500064, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500065, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500066, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500067, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500068, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500069, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500070, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500071, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500072, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500073, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500074, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500075, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500076, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500077, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500078, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500079, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500080, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500081, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500082, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500083, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500084, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500085, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500086, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500087, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500088, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500089, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500090, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500091, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500092, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500093, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500094, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500095, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500096, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500097, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500098, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500099, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500100, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500101, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500102, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500103, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500104, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500105, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500106, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500107, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500108, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500109, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500110, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500111, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500112, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500113, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500114, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500115, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500116, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500117, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500118, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500119, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500120, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500121, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500122, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500123, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500124, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500125, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500126, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500127, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500128, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500129, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500130, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500131, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500132, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500133, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500134, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500135, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500136, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500137, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500138, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500139, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500140, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500141, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500142, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500143, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500144, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500145, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500146, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500147, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500148, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500149, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500150, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500151, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500152, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500153, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500154, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500155, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500156, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500157, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500158, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500159, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500160, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500161, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500162, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500163, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500164, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500165, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500166, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500167, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500168, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500169, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500170, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500171, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500172, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500173, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500174, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500175, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500176, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500177, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500178, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500179, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500180, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500181, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500182, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500183, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500184, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500185, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500186, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500187, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500188, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500189, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500190, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500191, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500192, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500193, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500194, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500195, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500196, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500197, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500198, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500199, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500200, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500201, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500202, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500203, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500204, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500205, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500206, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500207, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500208, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500209, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500210, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500211, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500212, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500213, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500214, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500215, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500216, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500217, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500218, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500219, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500220, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500221, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500222, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500223, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500224, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500225, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500226, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500227, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500228, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500229, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500230, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500231, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500232, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500233, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500234, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500235, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500236, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500237, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500238, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500239, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500240, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500241, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500242, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500243, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500244, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500245, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500246, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500247, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500248, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500249, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500250, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500251, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500252, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500253, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500254, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500255, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500256, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500257, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500258, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500259, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500260, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500261, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500262, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500263, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500264, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500265, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500266, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500267, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500268, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500269, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500270, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500271, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 1_500272, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# ...
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700082, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700083, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700084, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700085, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700086, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700087, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700088, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700089, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700090, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700091, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700092, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700093, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700094, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700095, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700096, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700097, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700098, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700099, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700100, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700101, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700102, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700103, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700104, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700105, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700106, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700107, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700108, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700109, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700110, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700111, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700112, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700113, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700114, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700115, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700116, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700117, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700118, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700119, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700120, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700121, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700122, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700123, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700124, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700125, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700126, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700127, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700128, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700129, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700130, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700131, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700132, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700133, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700134, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700135, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700136, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700137, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700138, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700139, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700140, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700141, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700142, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700143, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700144, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700145, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700146, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700147, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700148, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700149, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700150, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700151, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700152, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700153, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700154, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700155, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700156, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700157, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700158, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700159, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700160, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700161, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700162, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700163, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700164, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700165, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700166, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700167, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700168, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700169, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700170, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700171, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Processing bearing: 2_700172, Data size: 2560
# Data size: 2560, Samples per window: 10, Number of windows: 256
# Data size: 2560, Samples per window: 10, Number of windows: 256
# 100%|██████████| 6/6 [33:11<00:00, 331.97s/it]
# Extracted features shape: (44032, 23)

# %%
# print(vibration_data_with_rul[['bearing_id', 'time_seconds', 'RUL_norm']].head())
import pickle
nom_fichier = "df_test_rul.pkl"

# Sauvegarde de la liste dans un fichier avec pickle
with open(nom_fichier, "wb") as fichier:
    pickle.dump(list_test_df, fichier)

print(f"Liste sauvegardée dans le fichier '{nom_fichier}'.")
# Out:
# Liste sauvegardée dans le fichier 'df_test_rul.pkl'.

# %%
len(list_test_df)
# Out:
# 6

# %%
df_merged = pd.concat(list_train_df, ignore_index=True)

# %%
X = df_merged.drop(columns=['bearing_id', 'window_index', 'RUL_norm'])
X.shape
# Out:
# (1377792, 222)

# %%
X = X.dropna()

# %%
X.shape
# Out:
# (1377792, 222)

# %%
X_normalized = (X - X.min()) / (X.max() - X.min())

# %%
X_normalized.describe()
# Out:
#              mean_h         std_h  peak_to_peak_h         rms_h    mean_abs_h  \
# count  1.377792e+06  1.377792e+06    1.377792e+06  1.377792e+06  1.377792e+06
# mean   5.786804e-01  1.568022e-02    1.721883e-02  1.456413e-02  1.371050e-02
# std    9.073555e-03  1.431249e-02    1.502734e-02  1.462755e-02  1.428179e-02
# min    0.000000e+00  0.000000e+00    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    5.762881e-01  8.588209e-03    9.665214e-03  7.695561e-03  7.016533e-03
# 50%    5.787203e-01  1.207222e-02    1.352381e-02  1.085125e-02  1.001618e-02
# 75%    5.810894e-01  1.832323e-02    2.021703e-02  1.672232e-02  1.570600e-02
# max    1.000000e+00  1.000000e+00    1.000000e+00  1.000000e+00  1.000000e+00
#
#           max_abs_h    skewness_h    kurtosis_h  form_factor_h  \
# count  1.377792e+06  1.377792e+06  1.377792e+06   1.377792e+06
# mean   1.909916e-02  4.836694e-01  1.753639e-01   1.211885e-01
# std    1.779840e-02  1.005046e-01  9.361923e-02   5.686452e-02
# min    0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    1.053725e-02  4.190518e-01  1.106646e-01   8.096772e-02
# 50%    1.481866e-02  4.837953e-01  1.554677e-01   1.134721e-01
# 75%    2.215525e-02  5.483390e-01  2.171258e-01   1.529990e-01
# max    1.000000e+00  1.000000e+00  1.000000e+00   1.000000e+00
#
#        crest_factor_h  ...  integral_impulse_factor_v  \
# count    1.377792e+06  ...               1.377792e+06
# mean     5.668876e-01  ...               2.823309e-01
# std      1.480223e-01  ...               1.216195e-01
# min      0.000000e+00  ...               0.000000e+00
# 25%      4.994644e-01  ...               1.781856e-01
# 50%      5.954458e-01  ...               3.124066e-01
# 75%      6.651110e-01  ...               3.699189e-01
# max      1.000000e+00  ...               1.000000e+00
#
#        integral_margin_factor_v  integral_energy_v  integral_moment_5_v  \
# count              1.377792e+06       1.377792e+06         1.377792e+06
# mean               1.894631e-01       8.687563e-05         6.603333e-01
# std                8.886501e-02       2.505242e-03         9.940786e-04
# min                0.000000e+00       0.000000e+00         0.000000e+00
# 25%                1.155580e-01       1.323548e-05         6.603346e-01
# 50%                2.029960e-01       2.700599e-05         6.603346e-01
# 75%                2.495518e-01       5.755122e-05         6.603346e-01
# max                1.000000e+00       1.000000e+00         1.000000e+00
#
#        integral_moment_6_v  integral_moment_7_v  integral_moment_8_v  \
# count         1.377792e+06         1.377792e+06         1.377792e+06
# mean          4.903168e-06         6.934527e-01         3.799052e-06
# std           1.668345e-03         8.586503e-04         1.461911e-03
# min           0.000000e+00         0.000000e+00         0.000000e+00
# 25%           3.562353e-14         6.934536e-01         1.263750e-18
# 50%           1.981079e-13         6.934536e-01         1.257320e-17
# 75%           1.159937e-12         6.934536e-01         1.332751e-16
# max           1.000000e+00         1.000000e+00         1.000000e+00
#
#        integral_moment_9_v  integral_moment_10_v  integral_moment_11_v
# count         1.377792e+06          1.377792e+06          1.377792e+06
# mean          7.094422e-01          3.088308e-06          7.281253e-01
# std           7.934329e-04          1.299828e-03          7.625892e-04
# min           0.000000e+00          0.000000e+00          0.000000e+00
# 25%           7.094430e-01          4.369788e-23          7.281260e-01
# 50%           7.094430e-01          7.809273e-22          7.281260e-01
# 75%           7.094430e-01          1.497767e-20          7.281260e-01
# max           1.000000e+00          1.000000e+00          1.000000e+00
#
# [8 rows x 222 columns]

# %%
X_normalized = X_normalized.dropna(axis=1)

# %%
from varclushi import VarClusHi

resclv = VarClusHi(X_normalized,maxeigval2=1,maxclus=None)
resclv.varclus()

# %%
resclv.rsquare
# Out:
#      Cluster                   Variable    RS_Own     RS_NC  RS_Ratio
# 0          0                      std_v  0.927756  0.915376  0.853702
# 1          0             peak_to_peak_v  0.927472  0.880343  0.606131
# 2          0                      rms_v  0.951252  0.896875  0.472707
# 3          0                 mean_abs_v  0.920459  0.892391  0.739171
# 4          0                  max_abs_v  0.938805  0.817758  0.335788
# ..       ...                        ...       ...       ...       ...
# 177       37         imf_entropy_4_tf_h  0.109717  0.006587  0.896185
# 178       37         imf_entropy_3_tf_h  0.541211  0.023706  0.469930
# 179       38  derivative_crest_factor_h  0.512603  0.527494  1.031516
# 180       38      derivative_skewness_v  0.512603  0.447526  0.882209
# 181       39      derivative_skewness_h  1.000000  0.275705  0.000000
#
# [182 rows x 5 columns]

# %%
print(X_normalized.isna().sum()[X_normalized.isna().sum()>0])# Si tout est à 0, il n'y a plus de NaN
# Out:
# energy_band_1_freq_h     1377792
# energy_band_2_freq_h     1377792
# energy_band_3_freq_h     1377792
# energy_band_4_freq_h     1377792
# energy_band_6_freq_h     1377792
# energy_band_7_freq_h     1377792
# energy_band_8_freq_h     1377792
# energy_band_9_freq_h     1377792
# energy_band_11_freq_h    1377792
# energy_band_12_freq_h    1377792
# energy_band_13_freq_h    1377792
# energy_band_14_freq_h    1377792
# energy_band_16_freq_h    1377792
# energy_band_17_freq_h    1377792
# energy_band_18_freq_h    1377792
# energy_band_19_freq_h    1377792
# energy_band_21_freq_h    1377792
# energy_band_22_freq_h    1377792
# energy_band_23_freq_h    1377792
# energy_band_24_freq_h    1377792
# energy_band_1_freq_v     1377792
# energy_band_2_freq_v     1377792
# energy_band_3_freq_v     1377792
# energy_band_4_freq_v     1377792
# energy_band_6_freq_v     1377792
# energy_band_7_freq_v     1377792
# energy_band_8_freq_v     1377792
# energy_band_9_freq_v     1377792
# energy_band_11_freq_v    1377792
# energy_band_12_freq_v    1377792
# energy_band_13_freq_v    1377792
# energy_band_14_freq_v    1377792
# energy_band_16_freq_v    1377792
# energy_band_17_freq_v    1377792
# energy_band_18_freq_v    1377792
# energy_band_19_freq_v    1377792
# energy_band_21_freq_v    1377792
# energy_band_22_freq_v    1377792
# energy_band_23_freq_v    1377792
# energy_band_24_freq_v    1377792
# dtype: int64

# %%
energy_band_1_freq_h     
energy_band_2_freq_h     
energy_band_3_freq_h     
energy_band_4_freq_h     
energy_band_6_freq_h     
energy_band_7_freq_h     
energy_band_8_freq_h     
energy_band_9_freq_h     
energy_band_11_freq_h    
energy_band_12_freq_h    
energy_band_13_freq_h    
energy_band_14_freq_h    
energy_band_16_freq_h    
energy_band_17_freq_h    
energy_band_18_freq_h    
energy_band_19_freq_h    
energy_band_21_freq_h    
energy_band_22_freq_h    
energy_band_23_freq_h    
energy_band_24_freq_h    
energy_band_1_freq_v     
energy_band_2_freq_v     
energy_band_3_freq_v     
energy_band_4_freq_v     
energy_band_6_freq_v     
energy_band_7_freq_v     
energy_band_8_freq_v     
energy_band_9_freq_v     
energy_band_11_freq_v    
energy_band_12_freq_v   
energy_band_13_freq_v    
energy_band_14_freq_v    
energy_band_16_freq_v    
energy_band_17_freq_v    
energy_band_18_freq_v    
energy_band_19_freq_v    
energy_band_21_freq_v    
energy_band_22_freq_v    
energy_band_23_freq_v
energy_band_24_freq_v
